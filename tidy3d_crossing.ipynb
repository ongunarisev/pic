# %% [markdown]
# # Waveguide Crossing Tutorial

# %% [markdown]
# This tutorial notebook demonstrates how to perform a `Tidy3D` simulation on a waveguide crossing, similar to the [Cosine Taper Waveguide Crossing](https://docs.flexcompute.com/projects/tidy3d/en/latest/notebooks/WaveguideCrossing.html) notebook in our current example library. The crossing geometry is imported from a GDS file using `gdstk` library. A [ModeSource](https://docs.flexcompute.com/projects/tidy3d/en/latest/_autosummary/tidy3d.ModeSource.html?highlight=modesource) launches the fundamental TE mode. We want to make sure that the transmission efficiency to the waveguide on the right is high, while the transmission to the waveguides on the top and bottom is low. To characterize the S-parameters, we add three [ModeMonitors](https://docs.flexcompute.com/projects/tidy3d/en/latest/_autosummary/tidy3d.FluxMonitor.html?highlight=modemonitor), which will return the complex S-parameters after the simulation is complete. In addition, a [FieldMonitor](https://docs.flexcompute.com/projects/tidy3d/en/latest/_autosummary/tidy3d.FieldMonitor.html?highlight=fieldmonitor) is added to visualize the field distribution. An automatic non-uniform mesh is used such that the grid size is smaller on the waveguide area, where the fields are concentrated. For the boundaries of the simulation domain, perfectly matched layers (PML) are used to absorb the outgoing energy with minimal reflection, mimicking an infinite space.

# %% [markdown]
# ## Library Import

# %% [markdown]
# We will import a couple of libraries to help us build the simulation, submit the simulation job to the server, and postprocess the simulation results. Besides the main `tidy3d` library, `numpy` and `matplotlib` are used for numerical manipulation and result plotting. In addition, `gdstk` will be used to import the gds file and convert the structures in the gds file to `Tidy3D` geometries.

# %%
import numpy as np
import matplotlib.pyplot as plt

import gdstk

import tidy3d as td
import tidy3d.web as web
from tidy3d.plugins.mode import ModeSolver

# %% [markdown]
# ## Define Simulation Frequency (Wavelength)

# %% [markdown]
# The simulation is centered around 1550 nm with a wavelength range of 100 nm.

# %%
lda0 = 1.55  # central wavelength
ldas = np.linspace(1.5, 1.6, 101)  # wavelength range of interest

freq0 = td.C_0 / lda0  # corresponding central frequency
freqs = td.C_0 / ldas  # corresponding frequency range

fwidth = 0.5 * (np.max(freqs) - np.min(freqs))  # width of the excitation frequency spectrum

# %% [markdown]
# ## Define Materials

# %% [markdown]
# We will define two materials -- silicon and silica. In the wavelength range of interest, both materials have an approximately constant refractive index and nearly zero extinction coefficient. Therefore, we model them as non-dispersive and lossless media. If the simulation wavelength range is large such that dispersion and loss are of importance, we can incorporate them in other ways as introduced in the [dispersive materials tutorial](https://docs.flexcompute.com/projects/tidy3d/en/latest/notebooks/Dispersion.html).

# %%
n_si = 3.48  # silicon refractive index
si = td.Medium(permittivity=n_si**2)

n_sio2 = 1.44  # silicon oxide refractive index
sio2 = td.Medium(permittivity=n_sio2**2)

# %% [markdown]
# ## Import the Crossing Structure from a gds File

# %% [markdown]
# Next, we use `gdstk` to import the gds file. First, we need to specify the directory and file name of the gds file. In this case, the file is [ebeam_crossing4.gds](https://github.com/SiEPIC/SiEPIC_EBeam_PDK/blob/master/klayout_dot_config/tech/EBeam/gds/mature/ebeam_crossing4.gds), which is stored under the same directory as this notebook file.

# %%
gds_path = r"C:\Users\ongun\Desktop\EdX_Photonics\ebeam_crossing4.gds" # path of the gds file

lib = gdstk.read_gds(infile=gds_path)  # import gds file
cell = lib.top_level()[0]  # read cell

# %% [markdown]
# Now we will convert the cell into a `Tidy3D` [PolySlab](https://docs.flexcompute.com/projects/tidy3d/en/latest/_autosummary/tidy3d.PolySlab.html?highlight=polyslab) using the `from_gds()` method.
#
# The `slab_bounds` is set to `(-h/2,h/2)` such that the crossing has a thickness of *h=220 nm*.

# %%
h = 0.22  #thickness of the silicon layer

#convert the gds cell into a tidy3d PolySlab
crossing_gds = td.PolySlab.from_gds(
    cell,
    gds_layer=1,
    axis=2,
    slab_bounds=(-h/2, h/2),
)

# %% [markdown]
# To confirm the import is correct, we can use the `plot` method to visualize it.

# %%
crossing_gds[0].plot(z=0)
# Out:
# <Axes: title={'center': 'cross section at z=0.00'}, xlabel='x', ylabel='y'>

# %% [markdown]
# ## Define Structures

# %% [markdown]
# Next, we will make a `Tidy3D` [Structure](https://docs.flexcompute.com/projects/tidy3d/en/latest/_autosummary/tidy3d.Structure.html?highlight=structure). Essentially, a [Structure](https://docs.flexcompute.com/projects/tidy3d/en/latest/_autosummary/tidy3d.Structure.html?highlight=structure) is a combination of geometry and medium. For the waveguide crossing, the geometry is the previously defined [PolySlab](https://docs.flexcompute.com/projects/tidy3d/en/latest/_autosummary/tidy3d.PolySlab.html?highlight=polyslab) and the medium is set to `si`.

# %%
crossing = td.Structure(geometry=crossing_gds[0],
            medium=si)

# %% [markdown]
# Another [Structure](https://docs.flexcompute.com/projects/tidy3d/en/latest/_autosummary/tidy3d.Structure.html?highlight=structure) in the simulation is the substrate, which is a [Box](https://docs.flexcompute.com/projects/tidy3d/en/latest/_autosummary/tidy3d.Box.html?highlight=box) geometry and `sio2` medium. We define the box using the `from_bounds` method here for convenience.
#
# In FDTD simulations, it is very important to make sure the structures  extend into the simulation boundaries instead of stopping right at the boundaries, which is likely to cause numerical issues. Therefore, the substrate is defined to be much larger than the waveguide crossing. Later, we will define the simulation domain such that the straight waveguides and the substrate all extend into the boundaries.

# %%
substrate = td.Structure(geometry=td.Box.from_bounds(rmin=(-10,-10,-10), rmax=(10,10,-h/2)), medium=sio2)

# %% [markdown]
# ## Define Sources and Monitors

# %% [markdown]
# For excitation, we define a [ModeSource](https://docs.flexcompute.com/projects/tidy3d/en/latest/_autosummary/tidy3d.ModeSource.html?highlight=modesource) to inject the fundamental TE mode from the left straight waveguide into the crossing. Three [ModeMonitors](https://docs.flexcompute.com/projects/tidy3d/en/latest/_autosummary/tidy3d.FluxMonitor.html?highlight=modemonitor) are added. One in the straight waveguide on the right (port 1), one on the top (port 2), and one on the left (port 3). These three monitors will measure the complex S-parameters. Due to symmetry, the transmission to the top waveguide is identical to that in the bottom waveguide so we do not need to define another monitor there. Lastly, a [FieldMonitor](https://docs.flexcompute.com/projects/tidy3d/en/latest/_autosummary/tidy3d.FieldMonitor.html?highlight=fieldmonitor) is added in the *xy* plane so that we can visualize the field distribution after the simulation to see how the mode propagates.

# %%
mode_spec = td.ModeSpec(num_modes=1, target_neff=n_si)

#define a mode source
mode_source = td.ModeSource(
    center=(-3.95, 0, 0),
    size=(0, 2, 8 * h),
    source_time=td.GaussianPulse(freq0=freq0, fwidth=fwidth),
    direction="+",
    mode_spec=mode_spec,
    mode_index=0,
)

#define a mode monitor on the right waveguide
port3 = td.ModeMonitor(
    center=(4, 0, 0),
    size=(0, 2, 8 * h),
    freqs=freqs,
    name="port3",
    mode_spec = mode_spec
)

#define a mode monitor on the top waveguide
port2 = td.ModeMonitor(
    center=(0, 4, 0),
    size=(2, 0, 8 * h),
    freqs=freqs,
    name="port2",
    mode_spec = mode_spec
)

#define a mode monitor on the left waveguide
port1 = td.ModeMonitor(
    center=(-4, 0, 0),  #port1 is slightly offset from the mode source
    size=(0, 2, 8 * h),
    freqs=freqs,
    name="port1",
    mode_spec = mode_spec,
)

#define a field monitor in the xy plane
field_monitor = td.FieldMonitor(
    center=(0, 0, 0), size=(td.inf, td.inf, 0), freqs=[freq0], name="field"
)

# %% [markdown]
# ## Define Simulation

# %% [markdown]
# Now we are ready to define a `Tidy3D` [Simulation](https://docs.flexcompute.com/projects/tidy3d/en/latest/_autosummary/tidy3d.Simulation.html). The run time is set to 1 ps, which should allow the injected energy to sufficiently decay. An automatic nonuniform grid is used with the minimum steps per wavelength set to 15, which should resolve the fields pretty well in this model. PML is added to all boundaries to absorb the outgoing radiation. The simulation domain size is set to 9 *&mu;m* by 9 *&mu;m* in the *x* and *y* directions. This ensures that the straight waveguides extend into the outer PML. The background medium is set to silica, which represents the top cladding. If no cladding or other material is used for cladding, the background medium needs to be changed accordingly.

# %%
run_time = 1e-12

sim = td.Simulation(
    size=(9, 9, 10 * h),
    grid_spec=td.GridSpec.auto(min_steps_per_wvl=15, wavelength=lda0),
    structures=[crossing],
    sources=[mode_source],
    monitors=[port1, port2, port3, field_monitor],
    run_time=run_time,
    boundary_spec=td.BoundarySpec.all_sides(boundary=td.PML()),
    medium=sio2,
)
# Out:
# [23:11:25] WARNING: A bound of Simulation.structures[0] was detected as being within the simulation PML.  ]8;id=534896;file://C:\Users\ongun\.conda\envs\tidy3d_env\lib\site-packages\tidy3d\log.py\log.py]8;;\:]8;id=244340;file://C:\Users\ongun\.conda\envs\tidy3d_env\lib\site-packages\tidy3d\log.py#50\50]8;;\
#            We recommend extending structures to infinity or completely outside of the simulation PML to
#            avoid unexpected effects when the structures are not translationally invariant within the PML.
#            Skipping rest of structures.

# %% [markdown]
# Finally, we can use the `plot` method to visualize the simulation setup. We can see the source (green) and monitors (yellow) are all set up correctly.

# %%
sim.plot(z=0)
# Out:
# <Axes: title={'center': 'cross section at z=0.00'}, xlabel='x', ylabel='y'>

# %% [markdown]
# ## Visualize the Mode Field

# %% [markdown]
# An optional but recommended step in such a simulation is to visualize the mode field launched by the [ModeSource](https://docs.flexcompute.com/projects/tidy3d/en/latest/_autosummary/tidy3d.ModeSource.html?highlight=modesource). This will help us determine if we are launching the correct mode that we try to use. It also helps verify if the size of the [ModeSource](https://docs.flexcompute.com/projects/tidy3d/en/latest/_autosummary/tidy3d.ModeSource.html?highlight=modesource) is sufficiently large such that the field decays to zero at the boundaries of the source.
#
# `Tidy3D` provides a [ModeSolver](https://docs.flexcompute.com/projects/tidy3d/en/latest/_autosummary/tidy3d.plugins.ModeSolver.html?highlight=modesolver) plugin that you can use to inspect the modes. Here we demonstrate how to use it.

# %%
#define the mode solver
mode_solver = ModeSolver(
    simulation=sim,
    plane=td.Box(
        center=(-3.95, 0, 0),  #set to the same center as the mode source
        size=(0, 2, 8 * h),  #set to the same size as the mode source
    ),
    mode_spec=td.ModeSpec(num_modes=1, target_neff=n_si),
    freqs=[freq0],
)

#solve for the mode
mode_data = mode_solver.solve()

# %% [markdown]
# After running the [ModeSolver](https://docs.flexcompute.com/projects/tidy3d/en/latest/_autosummary/tidy3d.plugins.ModeSolver.html?highlight=modesolver), we can plot the mode fields. From the plots, we can confirm that the mode is the fundamental TE mode with the dominant polarization in the *y* direction.

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, tight_layout=True, figsize=(10, 3))
abs(mode_data.Ex.isel(mode_index=0)).plot(x="y", y="z", ax=ax1, cmap="magma")
abs(mode_data.Ey.isel(mode_index=0)).plot(x="y", y="z", ax=ax2, cmap="magma")
abs(mode_data.Ez.isel(mode_index=0)).plot(x="y", y="z", ax=ax3, cmap="magma")

ax1.set_title("|Ex(x, y)|")
ax1.set_aspect("equal")
ax2.set_title("|Ey(x, y)|")
ax2.set_aspect("equal")
ax3.set_title("|Ez(x, y)|")
ax3.set_aspect("equal")
plt.show()

# %% [markdown]
# ## Submit the Simulation Job to the Server

# %% [markdown]
# Now we are ready to submit the simulation job to the server for computation. After the simulation finishes, the monitor data will be automatically returned.

# %%
job = web.Job(simulation=sim, task_name="waveguide_crossing")
sim_data = job.run(path="data/simulation_data_wg_crossing.hdf5")
# Out:
# [23:12:01] Created task 'waveguide_crossing' with task_id                                             ]8;id=334757;file://C:\Users\ongun\.conda\envs\tidy3d_env\lib\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=925389;file://C:\Users\ongun\.conda\envs\tidy3d_env\lib\site-packages\tidy3d\web\webapi.py#139\139]8;;\
#            'fdve-11dba01d-5f2c-4767-9a31-5ebfdf3c7348v1'.
#            View task using web UI at                                                                  ]8;id=114123;file://C:\Users\ongun\.conda\envs\tidy3d_env\lib\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=19446;file://C:\Users\ongun\.conda\envs\tidy3d_env\lib\site-packages\tidy3d\web\webapi.py#141\141]8;;\
#            ]8;id=834046;https://tidy3d.simulation.cloud/workbench?taskId=fdve-11dba01d-5f2c-4767-9a31-5ebfdf3c7348v1\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=578518;https://tidy3d.simulation.cloud/workbench?taskId=fdve-11dba01d-5f2c-4767-9a31-5ebfdf3c7348v1\taskId]8;;\]8;id=834046;https://tidy3d.simulation.cloud/workbench?taskId=fdve-11dba01d-5f2c-4767-9a31-5ebfdf3c7348v1\=]8;;\]8;id=842558;https://tidy3d.simulation.cloud/workbench?taskId=fdve-11dba01d-5f2c-4767-9a31-5ebfdf3c7348v1\fdve]8;;\]8;id=834046;https://tidy3d.simulation.cloud/workbench?taskId=fdve-11dba01d-5f2c-4767-9a31-5ebfdf3c7348v1\-11dba01d-5f2c-4767-9a31-5ebfdf3c734]8;;\
#            ]8;id=834046;https://tidy3d.simulation.cloud/workbench?taskId=fdve-11dba01d-5f2c-4767-9a31-5ebfdf3c7348v1\8v1']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [23:12:08] status = queued                                                                            ]8;id=201390;file://C:\Users\ongun\.conda\envs\tidy3d_env\lib\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=455326;file://C:\Users\ongun\.conda\envs\tidy3d_env\lib\site-packages\tidy3d\web\webapi.py#271\271]8;;\
# Output()
# [23:12:14] status = preprocess                                                                        ]8;id=347225;file://C:\Users\ongun\.conda\envs\tidy3d_env\lib\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=46263;file://C:\Users\ongun\.conda\envs\tidy3d_env\lib\site-packages\tidy3d\web\webapi.py#265\265]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [23:12:22] Maximum FlexCredit cost: 0.038. Use 'web.real_cost(task_id)' to get the billed FlexCredit  ]8;id=572079;file://C:\Users\ongun\.conda\envs\tidy3d_env\lib\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=858232;file://C:\Users\ongun\.conda\envs\tidy3d_env\lib\site-packages\tidy3d\web\webapi.py#288\288]8;;\
#            cost after a simulation run.
#            starting up solver                                                                         ]8;id=391;file://C:\Users\ongun\.conda\envs\tidy3d_env\lib\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=845630;file://C:\Users\ongun\.conda\envs\tidy3d_env\lib\site-packages\tidy3d\web\webapi.py#292\292]8;;\
#            running solver                                                                             ]8;id=854923;file://C:\Users\ongun\.conda\envs\tidy3d_env\lib\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=41436;file://C:\Users\ongun\.conda\envs\tidy3d_env\lib\site-packages\tidy3d\web\webapi.py#302\302]8;;\
# Output()
# [23:13:27] early shutoff detected, exiting.                                                           ]8;id=382678;file://C:\Users\ongun\.conda\envs\tidy3d_env\lib\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=306362;file://C:\Users\ongun\.conda\envs\tidy3d_env\lib\site-packages\tidy3d\web\webapi.py#316\316]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#            status = postprocess                                                                       ]8;id=249374;file://C:\Users\ongun\.conda\envs\tidy3d_env\lib\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=306547;file://C:\Users\ongun\.conda\envs\tidy3d_env\lib\site-packages\tidy3d\web\webapi.py#333\333]8;;\
# Output()
# [23:13:52] status = success                                                                           ]8;id=172600;file://C:\Users\ongun\.conda\envs\tidy3d_env\lib\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=908902;file://C:\Users\ongun\.conda\envs\tidy3d_env\lib\site-packages\tidy3d\web\webapi.py#340\340]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [23:13:58] loading SimulationData from data/simulation_data.hdf5                                      ]8;id=605178;file://C:\Users\ongun\.conda\envs\tidy3d_env\lib\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=819632;file://C:\Users\ongun\.conda\envs\tidy3d_env\lib\site-packages\tidy3d\web\webapi.py#512\512]8;;\
# [23:13:58] WARNING: A bound of Simulation.structures[0] was detected as being within the simulation PML.  ]8;id=232921;file://C:\Users\ongun\.conda\envs\tidy3d_env\lib\site-packages\tidy3d\log.py\log.py]8;;\:]8;id=740946;file://C:\Users\ongun\.conda\envs\tidy3d_env\lib\site-packages\tidy3d\log.py#50\50]8;;\
#            We recommend extending structures to infinity or completely outside of the simulation PML to
#            avoid unexpected effects when the structures are not translationally invariant within the PML.
#            Skipping rest of structures.

# %% [markdown]
# ## Result Postprocessing and Visualization

# %% [markdown]
# Now the simulation is complete, we can postprocess and visualize the results. First, we plot the field intensity distribution in the *xy* plane using the data from the [FieldMonitor](https://docs.flexcompute.com/projects/tidy3d/en/latest/_autosummary/tidy3d.FieldMonitor.html?highlight=fieldmonitor). This can be conveniently done by using the `plot_field` method. From the plot, we can see the energy flow from the left waveguide to the right waveguide with minimal transmission to the top and bottom waveguides.

# %%
sim_data.plot_field("field", "int", f=freq0, vmin=0, vmax=3000)
# Out:
# [23:14:37] WARNING: 'int' field name is deprecated and will be removed in the future. Plese use           ]8;id=54257;file://C:\Users\ongun\.conda\envs\tidy3d_env\lib\site-packages\tidy3d\log.py\log.py]8;;\:]8;id=793420;file://C:\Users\ongun\.conda\envs\tidy3d_env\lib\site-packages\tidy3d\log.py#50\50]8;;\
#            field_name='E' and val='abs^2' for the same effect.
# <Axes: title={'center': 'cross section at z=0.00'}, xlabel='x', ylabel='y'>

# %% [markdown]
# Finally, we obtain the S-parameters and plot them in dB scale.

# %%
S11 = sim_data["port1"].amps.sel(direction='-').squeeze()
S21 = sim_data["port2"].amps.sel(direction='+').squeeze()
S31 = sim_data["port3"].amps.sel(direction='+').squeeze()

plt.plot(ldas, 20*np.log10(np.abs(S11)), label='S11')
plt.plot(ldas, 20*np.log10(np.abs(S21)), label='S21')
plt.plot(ldas, 20*np.log10(np.abs(S31)), label='S31')

plt.xlim(1.5, 1.6)
plt.xlabel("Wavelength ($\mu$m)")
plt.legend()

# %% [markdown]
# The other S-matrix elements can be deduced directly due to symmetry.

# %%
S22 = S33 = S44 = S11
S32 = S12 = S23 = S43 = S14 = S34 = S41 = S21
S42 = S13 = S24 = S31

# %% [markdown]
# ## Preprare the S-parameter File

# %% [markdown]
# Once we obtained the S-parameters, we can write them into a `crossing_smatrix.txt` file that can be used for circuit level simulation.

# %%
S_matrix = {
    'S11':S11,
    'S21':S21,
    'S31':S31,
    'S41':S41,
    'S12':S12,
    'S22':S22,
    'S32':S32,
    'S42':S42,
    'S13':S13,
    'S23':S23,
    'S33':S33,
    'S43':S43,
    'S14':S14,
    'S24':S24,
    'S34':S34,
    'S44':S44,   
}

with open("crossing_smatrix.txt" , 'w') as f:
    f.write('[2,2]\n')
    
    for key in S_matrix:
        f.write(f'("port {key[1]}","TE",1,"port {key[2]}",1,"transmission")\n')
        f.write('(101,3)\n')
        np.savetxt(f, np.squeeze(np.dstack((freqs, np.abs(S_matrix[key]), np.angle(S_matrix[key])))), 
                   delimiter=' ', newline='\n')
